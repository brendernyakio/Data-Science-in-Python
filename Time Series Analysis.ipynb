# %%
#!pip install pmdarima

# %%
import pandas as pd
import numpy as np
from pmdarima import auto_arima
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA

from sklearn.metrics import mean_absolute_error, mean_squared_error
import warnings
warnings.filterwarnings("ignore")

data = pd.read_csv("murban.csv")
data.head()
# Out:
#      Months  crude_oil_prices
# 0  1/1/2003             29.60
# 1  2/1/2003             31.70
# 2  3/1/2003             29.10
# 3  4/1/2003             25.00
# 4  5/1/2003             25.85

# %%
data.tail()
# Out:
#             crude_oil_prices
# Months
# 2023-08-01             87.33
# 2023-09-01             94.60
# 2023-10-01             91.78
# 2023-11-01             84.92
# 2023-12-01             79.00

# %% [markdown]
# ## Convert to datetime and set index

# %%
data['Months'] = pd.to_datetime(data['Months'])
data.set_index('Months', inplace = True)

# %% [markdown]
# ## Extract the series of interest

# %%
crude = data['crude_oil_prices']

# %% [markdown]
# ## Plot time series

# %%
def plot_series(series, title="Time Series Plot For Crude Oil Price"):
    plt.figure(figsize=(6,4))
    plt.plot(series, color='purple', linewidth=2)
    plt.title(title)
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.grid()
    plt.show()
plot_series(crude)

# %% [markdown]
# ## Check Stationarity(ADF Test)

# %%
#H0:The series is non-stationary
#H1:The series is stationary

def check_stationarity(series):
    result = adfuller(series)
    print("ADF Statistic:", result[0])
    print("p-value:", result[1])
    if result[1] < 0.05:
        print("The series is stationary.")
    else:
        print("The series is non-stationary.")

check_stationarity(crude)
# Out:
# ADF Statistic: -2.824448334341283
# p-value: 0.05486546859967574
# The series is non-stationary.

# %% [markdown]
# ## Differencing

# %%
crude_diff = crude.diff().dropna()
plot_series(crude_diff, title="Differenced Time Series")
check_stationarity(crude_diff)
# Out:
# ADF Statistic: -8.934943433942943
# p-value: 9.590447049349964e-15
# The series is stationary.

# %% [markdown]
# ## Time Series Decompostion

# %%
decomposition = seasonal_decompose(crude, model='additive', period=12)
decomposition.plot()
plt.show()

# %% [markdown]
# ## Plot ACF and PACF

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))
plot_acf(crude, ax=axes[0])
plot_pacf(crude, ax=axes[1])
plt.show()

# %% [markdown]
# ## Fit ARIMA model using auto_arima

# %%
model = auto_arima(crude, seasonal=True, m=12, trace=True, suppress_warnings=True)
print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=1598.325, Time=0.51 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1637.599, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1597.562, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1604.905, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1635.846, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1595.941, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=1597.471, Time=0.13 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=1599.020, Time=0.16 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=1597.815, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1597.871, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1603.178, Time=0.05 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=1599.256, Time=0.21 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=1594.036, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=1595.650, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,1)[12]             : AIC=1595.557, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,1)[12]             : AIC=1597.108, Time=0.13 sec
#  ARIMA(2,1,0)(0,0,0)[12]             : AIC=1595.917, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=1595.969, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=1601.334, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[12]             : AIC=1597.347, Time=0.09 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[12]
# Total fit time: 2.087 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  252
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                -795.018
# Date:                Sun, 17 May 2026   AIC                           1594.036
# Time:                        23:49:36   BIC                           1601.087
# Sample:                    01-01-2003   HQIC                          1596.873
#                          - 12-01-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4001      0.038     10.499      0.000       0.325       0.475
# sigma2        32.9909      2.290     14.409      0.000      28.503      37.478
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                25.85
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.11   Skew:                            -0.40
# Prob(H) (two-sided):                  0.65   Kurtosis:                         4.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### Fit and Forecast

# %%
darima_model = ARIMA(crude, order=model.order).fit()
forecast_values = darima_model.forecast(steps=12)
forecast_values
# Out:
# 2024-01-01    76.631158
# 2024-02-01    75.683284
# 2024-03-01    75.303999
# 2024-04-01    75.152232
# 2024-05-01    75.091503
# 2024-06-01    75.067203
# 2024-07-01    75.057479
# 2024-08-01    75.053589
# 2024-09-01    75.052032
# 2024-10-01    75.051409
# 2024-11-01    75.051160
# 2024-12-01    75.051060
# Freq: MS, Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Plot Forecast

# %%
plt.figure(figsize=(10,5))
plt.plot(crude, label="Actual")
plt.plot(pd.date_range(crude.index[-1], periods=13, freq='ME')[1:], forecast_values, label="Forecast", color='red')    
plt.title("ARIMA Forecast for Crude Oil Price")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.show()

# %%
# performance Metrics
def evaluate_forecast(actual, predicted):
    mae = mean_absolute_error(actual, predicted)
    mse = mean_squared_error(actual, predicted)
    rmse = np.sqrt(mse)
    print(f"MAE:{mae}, MSE:{mse},RMSE:{rmse}")

evaluate_forecast(crude[-12:], forecast_values)
# Out:
# MAE:7.711157760816447, MSE:93.00239669873592,RMSE:9.64377502323317
